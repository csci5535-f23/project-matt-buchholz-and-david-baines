# %%
DRIVE_PREFIX = '/content/drive/MyDrive/Colab Notebooks/Code LLMs/'
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install accelerate -U
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 4.2 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import notebook_login

# %%
notebook_login()
#

# %%
import sys
import torch
sys.path.append(DRIVE_PREFIX)
import data_loader

# %%
import torch.nn as nn
from torch.utils.data import DataLoader

# %%
# from https://github.com/microsoft/CodeXGLUE/tree/main/Code-Code/CodeCompletion-token/dataset/py150

# Python 150k code completion dataset:


# Download the file
# !wget http://files.srl.inf.ethz.ch/data/py150_files.tar.gz

# !mkdir py150_files
# !tar -C py150_files -zxvf py150_files.tar.gz
# !rm py150_files.tar.gz

# Move to the py150_files directory
# %cd py150_files

# !tar -zxvf data.tar.gz
# !rm data.tar.gz

# %cd ../

# %%
# %cd ../
# Out:
# /content

# %%
# !python '/content/drive/MyDrive/Colab Notebooks/Code LLMs/preprocess.py' --base_dir=py150_files --output_dir=token_completion
# Out:
# train: 0 are done
# train: 10000 are done
# train: 20000 are done
# train: 30000 are done
# train: 40000 are done
# train: 50000 are done
# train: 60000 are done
# train: 70000 are done
# train: 80000 are done
# train: 90000 are done
# dev: 0 are done
# test: 0 are done
# test: 10000 are done
# test: 20000 are done
# test: 30000 are done
# test: 40000 are done

# %%
# train on code completion
